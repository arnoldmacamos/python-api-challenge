# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={api_key}&units={units}&q="

list_ctw = [];  #list of city weather

print('Beginning Data Retrieval')
print('--------------------------------------')
for index, city in enumerate(cities, start = 1) :
    response = requests.get(query_url + city)
    
    print(f"Processing Record ({index}) {city} ")
    if(response.status_code == 200):
        response_json = response.json()
        list_ctw.append({'city': response_json['name'],
                           'cloudiness': response_json['clouds']['all'],
                           'country': response_json['sys']['country'],
                           'date': response_json['dt'],
                           'humidity': response_json['main']['humidity'],
                           'lat': response_json['coord']['lat'],
                           'lng': response_json['coord']['lon'],
                           'max_temp' : response_json['main']['temp_max'],
                           'wind_speed': response_json['wind']['speed']               
                          })
    else:
        print("City not found. Skipping...")

df_ctf = pd.DataFrame(list_ctw)
# Out:
# Beginning Data Retrieval
# --------------------------------------
# Processing Record (1) juba
# Processing Record (2) codrington
# Processing Record (3) bethel
# Processing Record (4) rikitea
# Processing Record (5) penzance
# Processing Record (6) comodoro rivadavia
# Processing Record (7) clyde river
# Processing Record (8) belushya guba
# City not found. Skipping...
# Processing Record (9) tuktoyaktuk
# Processing Record (10) punta arenas
# Processing Record (11) ucluelet
# Processing Record (12) carnarvon
# Processing Record (13) puerto ayora
# Processing Record (14) attawapiskat
# City not found. Skipping...
# Processing Record (15) saint-philippe
# Processing Record (16) palabuhanratu
# City not found. Skipping...
# Processing Record (17) ushuaia
# Processing Record (18) tasiilaq
# Processing Record (19) grindavik
# Processing Record (20) port perry
# Processing Record (21) meulaboh
# Processing Record (22) taolanaro
# City not found. Skipping...
# Processing Record (23) new norfolk
# Processing Record (24) busselton
# Processing Record (25) thinadhoo
# Processing Record (26) balimo
# City not found. Skipping...
# Processing Record (27) mataura
# Processing Record (28) bath
# Processing Record (29) narsaq
# Processing Record (30) kodiak
# Processing Record (31) sault sainte marie
# Processing Record (32) barrow
# Processing Record (33) ponta do sol
# Processing Record (34) hegang
# Processing Record (35) seminole
# Processing Record (36) tsihombe
# City not found. Skipping...
# Processing Record (37) ancud
# Processing Record (38) dudinka
# Processing Record (39) sanmenxia
# Processing Record (40) arraial do cabo
# Processing Record (41) uwayl
# City not found. Skipping...
# Processing Record (42) prince albert
# Processing Record (43) cidreira
# Processing Record (44) avera
# Processing Record (45) funtua
# Processing Record (46) aklavik
# Processing Record (47) rijeka
# Processing Record (48) saint-joseph
# Processing Record (49) dongying
# Processing Record (50) cherskiy
# Processing Record (51) mantamados
# Processing Record (52) chilakalurupet
# Processing Record (53) upernavik
# Processing Record (54) chalinze
# Processing Record (55) hobart
# Processing Record (56) marzuq
# Processing Record (57) jamestown
# Processing Record (58) dikson
# Processing Record (59) longyearbyen
# Processing Record (60) corinto
# Processing Record (61) illoqqortoormiut
# City not found. Skipping...
# Processing Record (62) torbay
# Processing Record (63) saleaula
# City not found. Skipping...
# Processing Record (64) brae
# Processing Record (65) isangel
# Processing Record (66) rawson
# Processing Record (67) hilo
# Processing Record (68) tasbuget
# City not found. Skipping...
# Processing Record (69) albany
# Processing Record (70) airai
# Processing Record (71) guerrero negro
# Processing Record (72) kapaa
# Processing Record (73) prince rupert
# Processing Record (74) tombouctou
# Processing Record (75) butaritari
# Processing Record (76) klaksvik
# Processing Record (77) korla
# City not found. Skipping...
# Processing Record (78) thompson
# Processing Record (79) hobyo
# Processing Record (80) bluff
# Processing Record (81) castro
# Processing Record (82) tumannyy
# City not found. Skipping...
# Processing Record (83) barentsburg
# City not found. Skipping...
# Processing Record (84) iqaluit
# Processing Record (85) zabol
# Processing Record (86) solnechnyy
# Processing Record (87) yulara
# Processing Record (88) kilis
# Processing Record (89) hermanus
# Processing Record (90) bijie
# Processing Record (91) lebu
# Processing Record (92) siuna
# Processing Record (93) burns lake
# Processing Record (94) savannah bight
# Processing Record (95) ust-kamchatsk
# City not found. Skipping...
# Processing Record (96) norman wells
# Processing Record (97) georgetown
# Processing Record (98) ilulissat
# Processing Record (99) port alfred
# Processing Record (100) mayo
# Processing Record (101) sarangani
# Processing Record (102) tiksi
# Processing Record (103) oktyabrskiy
# Processing Record (104) mae hong son
# Processing Record (105) cayenne
# Processing Record (106) santa cruz do sul
# Processing Record (107) namibe
# Processing Record (108) kodinsk
# Processing Record (109) vardo
# Processing Record (110) kavieng
# Processing Record (111) morondava
# Processing Record (112) boli
# Processing Record (113) college
# Processing Record (114) rio gallegos
# Processing Record (115) bulaevo
# Processing Record (116) waitati
# Processing Record (117) khatanga
# Processing Record (118) bontang
# Processing Record (119) sur
# Processing Record (120) ribeira grande
# Processing Record (121) ayan
# Processing Record (122) turnhout
# Processing Record (123) marihatag
# Processing Record (124) vaini
# Processing Record (125) jinchang
# Processing Record (126) itaqui
# Processing Record (127) tambura
# City not found. Skipping...
# Processing Record (128) avarua
# Processing Record (129) provideniya
# Processing Record (130) qaanaaq
# Processing Record (131) urucui
# Processing Record (132) koshurnikovo
# Processing Record (133) alice springs
# Processing Record (134) bjerkvik
# Processing Record (135) goderich
# Processing Record (136) wanning
# Processing Record (137) bredasdorp
# Processing Record (138) tazovskiy
# Processing Record (139) quatre cocos
# Processing Record (140) atar
# Processing Record (141) yellowknife
# Processing Record (142) sabang
# Processing Record (143) coihaique
# Processing Record (144) kafanchan
# Processing Record (145) abay
# Processing Record (146) mokokchung
# Processing Record (147) sawai madhopur
# Processing Record (148) chiredzi
# Processing Record (149) soyo
# Processing Record (150) rocha
# Processing Record (151) domat
# Processing Record (152) nome
# Processing Record (153) sioux falls
# Processing Record (154) sulangan
# Processing Record (155) ijaki
# City not found. Skipping...
# Processing Record (156) guicheng
# City not found. Skipping...
# Processing Record (157) san policarpo
# Processing Record (158) kita
# Processing Record (159) bilibino
# Processing Record (160) cap-chat
# Processing Record (161) beroroha
# Processing Record (162) goundam
# Processing Record (163) lasa
# Processing Record (164) vila
# Processing Record (165) ammon
# Processing Record (166) pevek
# Processing Record (167) faya
# Processing Record (168) cape town
# Processing Record (169) fort nelson
# Processing Record (170) east london
# Processing Record (171) geraldton
# Processing Record (172) ust-ishim
# Processing Record (173) atuona
# Processing Record (174) nantucket
# Processing Record (175) lagoa
# Processing Record (176) palmer
# Processing Record (177) autazes
# Processing Record (178) mbarara
# Processing Record (179) salalah
# Processing Record (180) karakendzha
# City not found. Skipping...
# Processing Record (181) zelenoborsk
# Processing Record (182) cockburn town
# Processing Record (183) mahebourg
# Processing Record (184) lavrentiya
# Processing Record (185) arlington
# Processing Record (186) temaraia
# City not found. Skipping...
# Processing Record (187) cabo san lucas
# Processing Record (188) stara vyzhivka
# Processing Record (189) ostersund
# Processing Record (190) esperance
# Processing Record (191) pekan
# Processing Record (192) mareeba
# Processing Record (193) srednekolymsk
# Processing Record (194) liku
# Processing Record (195) ilinsko-podomskoye
# City not found. Skipping...
# Processing Record (196) hay river
# Processing Record (197) nanakuli
# Processing Record (198) chokurdakh
# Processing Record (199) pochutla
# Processing Record (200) hasaki
# Processing Record (201) poum
# Processing Record (202) nikolskoye
# Processing Record (203) jiuquan
# Processing Record (204) rockland
# Processing Record (205) zhoukou
# Processing Record (206) aybak
# City not found. Skipping...
# Processing Record (207) aloleng
# Processing Record (208) nemuro
# Processing Record (209) saint george
# Processing Record (210) chuy
# Processing Record (211) kahului
# Processing Record (212) souillac
# Processing Record (213) saint-augustin
# Processing Record (214) port-gentil
# Processing Record (215) nieuw amsterdam
# Processing Record (216) saskylakh
# Processing Record (217) ostrovnoy
# Processing Record (218) kyshtovka
# Processing Record (219) puerto montt
# Processing Record (220) port elizabeth
# Processing Record (221) kalmunai
# Processing Record (222) helong
# Processing Record (223) bugama
# Processing Record (224) ahipara
# Processing Record (225) paamiut
# Processing Record (226) nelson bay
# Processing Record (227) samusu
# City not found. Skipping...
# Processing Record (228) skjervoy
# Processing Record (229) somerset
# Processing Record (230) marcona
# City not found. Skipping...
# Processing Record (231) shitanjing
# Processing Record (232) khorixas
# Processing Record (233) bulgan
# Processing Record (234) dinsor
# City not found. Skipping...
# Processing Record (235) dwarka
# Processing Record (236) hithadhoo
# Processing Record (237) lazarev
# Processing Record (238) leningradskiy
# Processing Record (239) sinnamary
# Processing Record (240) antofagasta
# Processing Record (241) shenjiamen
# Processing Record (242) sorong
# Processing Record (243) nanortalik
# Processing Record (244) najran
# Processing Record (245) mordovo
# Processing Record (246) hualmay
# Processing Record (247) sao joao da barra
# Processing Record (248) algiers
# Processing Record (249) warwick
# Processing Record (250) laguna
# Processing Record (251) ugoofaaru
# Processing Record (252) hofn
# Processing Record (253) northam
# Processing Record (254) baruun-urt
# Processing Record (255) hamilton
# Processing Record (256) berlevag
# Processing Record (257) anadyr
# Processing Record (258) nouadhibou
# Processing Record (259) praia
# Processing Record (260) alekseyevsk
# Processing Record (261) victoria
# Processing Record (262) urucara
# Processing Record (263) cafarnaum
# Processing Record (264) tilichiki
# Processing Record (265) mehamn
# Processing Record (266) kutum
# Processing Record (267) matagami
# Processing Record (268) ambodifototra
# City not found. Skipping...
# Processing Record (269) touros
# Processing Record (270) brewster
# Processing Record (271) paucartambo
# City not found. Skipping...
# Processing Record (272) matameye
# City not found. Skipping...
# Processing Record (273) smithers
# Processing Record (274) alyangula
# Processing Record (275) itarema
# Processing Record (276) tczew
# Processing Record (277) pangnirtung
# Processing Record (278) micoud
# Processing Record (279) fairbanks
# Processing Record (280) port lincoln
# Processing Record (281) majene
# Processing Record (282) bang mun nak
# Processing Record (283) necochea
# Processing Record (284) havoysund
# Processing Record (285) adrar
# Processing Record (286) arman
# Processing Record (287) san javier
# Processing Record (288) talnakh
# Processing Record (289) bathsheba
# Processing Record (290) shelburne
# Processing Record (291) mar del plata
# Processing Record (292) kiunga
# Processing Record (293) awbari
# Processing Record (294) vladyslavivka
# Processing Record (295) mys shmidta
# City not found. Skipping...
# Processing Record (296) kenai
# Processing Record (297) karratha
# Processing Record (298) houma
# Processing Record (299) yerbogachen
# Processing Record (300) oeiras
# Processing Record (301) ust-nera
# Processing Record (302) bolungarvik
# City not found. Skipping...
# Processing Record (303) tabulbah
# City not found. Skipping...
# Processing Record (304) betul
# Processing Record (305) cururupu
# Processing Record (306) minab
# Processing Record (307) olbernhau
# Processing Record (308) novyy urengoy
# Processing Record (309) pampas
# Processing Record (310) ngunguru
# Processing Record (311) fortuna
# Processing Record (312) kingman
# Processing Record (313) periyapatti
# Processing Record (314) jalu
# Processing Record (315) bantry
# City not found. Skipping...
# Processing Record (316) bilma
# Processing Record (317) port hardy
# Processing Record (318) mahibadhoo
# Processing Record (319) achisay
# City not found. Skipping...
# Processing Record (320) pisco
# Processing Record (321) amderma
# City not found. Skipping...
# Processing Record (322) aldan
# Processing Record (323) tamiahua
# Processing Record (324) sakaiminato
# Processing Record (325) wasilla
# Processing Record (326) kuche
# City not found. Skipping...
# Processing Record (327) fergus falls
# Processing Record (328) labutta
# City not found. Skipping...
# Processing Record (329) nisia floresta
# Processing Record (330) zhigansk
# Processing Record (331) caravelas
# Processing Record (332) port macquarie
# Processing Record (333) lure
# Processing Record (334) karauzyak
# City not found. Skipping...
# Processing Record (335) korenovsk
# Processing Record (336) katsuura
# Processing Record (337) rabo de peixe
# Processing Record (338) gravdal
# Processing Record (339) malwan
# City not found. Skipping...
# Processing Record (340) grand centre
# City not found. Skipping...
# Processing Record (341) teknaf
# Processing Record (342) abu zabad
# Processing Record (343) sao gabriel da cachoeira
# Processing Record (344) moengo
# Processing Record (345) dryden
# Processing Record (346) gedo
# Processing Record (347) tarko-sale
# Processing Record (348) kupang
# Processing Record (349) taltal
# Processing Record (350) husavik
# Processing Record (351) faribault
# Processing Record (352) huron
# Processing Record (353) salisbury
# Processing Record (354) kathu
# Processing Record (355) petropavlovsk-kamchatskiy
# Processing Record (356) micheweni
# Processing Record (357) ambulu
# Processing Record (358) puksoozero
# Processing Record (359) san-pedro
# Processing Record (360) severo-kurilsk
# Processing Record (361) sao filipe
# Processing Record (362) onega
# Processing Record (363) dubbo
# Processing Record (364) alofi
# Processing Record (365) mrirt
# City not found. Skipping...
# Processing Record (366) puerto del rosario
# Processing Record (367) mergui
# City not found. Skipping...
# Processing Record (368) bubaque
# Processing Record (369) samarai
# Processing Record (370) stromness
# Processing Record (371) bako
# Processing Record (372) luganville
# Processing Record (373) viedma
# Processing Record (374) chaiya
# Processing Record (375) vostok
# Processing Record (376) dingle
# Processing Record (377) severo-yeniseyskiy
# Processing Record (378) ignalina
# Processing Record (379) biak
# Processing Record (380) sorland
# Processing Record (381) koupela
# Processing Record (382) faanui
# Processing Record (383) veinticinco de mayo
# Processing Record (384) te anau
# Processing Record (385) kununurra
# Processing Record (386) praia da vitoria
# Processing Record (387) sambava
# Processing Record (388) haines junction
# Processing Record (389) irbit
# Processing Record (390) grand river south east
# City not found. Skipping...
# Processing Record (391) cabedelo
# Processing Record (392) puerto baquerizo moreno
# Processing Record (393) saint anthony
# Processing Record (394) bay roberts
# Processing Record (395) mach
# Processing Record (396) saint-pierre
# Processing Record (397) cleveland
# Processing Record (398) luis correia
# Processing Record (399) kruisfontein
# Processing Record (400) khani
# Processing Record (401) mount isa
# Processing Record (402) baiyin
# Processing Record (403) sarahan
# Processing Record (404) porto belo
# Processing Record (405) espanola
# Processing Record (406) nanae
# Processing Record (407) kilgore
# Processing Record (408) barcelos
# Processing Record (409) palana
# Processing Record (410) plouzane
# Processing Record (411) taoudenni
# Processing Record (412) galiwinku
# City not found. Skipping...
# Processing Record (413) macaracas
# Processing Record (414) puerto escondido
# Processing Record (415) mullaitivu
# City not found. Skipping...
# Processing Record (416) krasnousolskiy
# City not found. Skipping...
# Processing Record (417) sosnovo-ozerskoye
# Processing Record (418) belaya gora
# Processing Record (419) pakxan
# Processing Record (420) san cristobal
# Processing Record (421) road town
# Processing Record (422) tabou
# Processing Record (423) araouane
# Processing Record (424) susah
# City not found. Skipping...
# Processing Record (425) kharp
# Processing Record (426) tarakan
# Processing Record (427) lazaro cardenas
# Processing Record (428) westport
# Processing Record (429) san juan
# Processing Record (430) sapele
# Processing Record (431) inverness
# Processing Record (432) tautira
# Processing Record (433) sitka
# Processing Record (434) arlit
# Processing Record (435) nchelenge
# Processing Record (436) byron bay
# Processing Record (437) belmonte
# Processing Record (438) talcahuano
# Processing Record (439) udachnyy
# Processing Record (440) katangli
# Processing Record (441) bambous virieux
# Processing Record (442) kulhudhuffushi
# Processing Record (443) chalmette
# Processing Record (444) bafq
# Processing Record (445) dianopolis
# City not found. Skipping...
# Processing Record (446) altamira
# Processing Record (447) san luis
# Processing Record (448) mathathane
# Processing Record (449) mabaruma
# Processing Record (450) ludhiana
# Processing Record (451) uthai thani
# Processing Record (452) luderitz
# Processing Record (453) chlorakas
# City not found. Skipping...
# Processing Record (454) soderhamn
# Processing Record (455) vuktyl
# Processing Record (456) usuki
# Processing Record (457) ambovombe
# Processing Record (458) okhotsk
# Processing Record (459) san patricio
# Processing Record (460) paulista
# Processing Record (461) anyang
# Processing Record (462) mentok
# City not found. Skipping...
# Processing Record (463) saint-georges
# Processing Record (464) turukhansk
# Processing Record (465) tessalit
# Processing Record (466) craig
# Processing Record (467) beaver dam
# Processing Record (468) andapa
# Processing Record (469) kavaratti
# Processing Record (470) metro
# Processing Record (471) kalach-na-donu
# Processing Record (472) komsomolskiy
# Processing Record (473) champasak
# Processing Record (474) wynyard
# Processing Record (475) yeppoon
# Processing Record (476) great bend
# Processing Record (477) general roca
# Processing Record (478) kalabo
# Processing Record (479) vilhena
# Processing Record (480) keti bandar
# Processing Record (481) chicla
# Processing Record (482) biscarrosse
# Processing Record (483) lata
# Processing Record (484) labuan
# Processing Record (485) machacamarca
# Processing Record (486) kaitangata
# Processing Record (487) aflu
# City not found. Skipping...
# Processing Record (488) dergaon
# Processing Record (489) mangrol
# Processing Record (490) padang
# Processing Record (491) macara
# City not found. Skipping...
# Processing Record (492) kattivakkam
# Processing Record (493) kadykchan
# City not found. Skipping...
# Processing Record (494) ranau
# Processing Record (495) culebra
# Processing Record (496) nyurba
# Processing Record (497) huoqiu
# Processing Record (498) vestmanna
# Processing Record (499) qaqortoq
# Processing Record (500) coahuayana
# Processing Record (501) roald
# Processing Record (502) matadi
# Processing Record (503) mogadishu
# Processing Record (504) jacareacanga
# Processing Record (505) havelock
# Processing Record (506) rosarito
# Processing Record (507) onokhino
# Processing Record (508) dongsheng
# Processing Record (509) bowen
# Processing Record (510) vaitupu
# City not found. Skipping...
# Processing Record (511) vammala
# Processing Record (512) zhireken
# Processing Record (513) maputo
# Processing Record (514) pacific grove
# Processing Record (515) sierra vista
# Processing Record (516) alugan
# Processing Record (517) tianmen
# Processing Record (518) hunza
# City not found. Skipping...
# Processing Record (519) north bend
# Processing Record (520) champerico
# Processing Record (521) cam ranh
# Processing Record (522) otane
# Processing Record (523) lompoc
# Processing Record (524) valley station
# Processing Record (525) malakal
# City not found. Skipping...
# Processing Record (526) buala
# Processing Record (527) stepnogorsk
# Processing Record (528) chumikan
# Processing Record (529) makakilo city
# Processing Record (530) kendari
# Processing Record (531) tame
# Processing Record (532) kamenka
# Processing Record (533) syamzha
# Processing Record (534) mellieha
# Processing Record (535) kamaishi
# Processing Record (536) luanda
# Processing Record (537) smidovich
# Processing Record (538) koroni
# Processing Record (539) vestmannaeyjar
# Processing Record (540) nogliki
# Processing Record (541) sokolo
# Processing Record (542) bengkulu
# City not found. Skipping...
# Processing Record (543) scranton
# Processing Record (544) saldanha
# Processing Record (545) ust-kan
# Processing Record (546) port hedland
# Processing Record (547) namatanai
# Processing Record (548) ballina
# Processing Record (549) listowel
# Processing Record (550) tuatapere
# Processing Record (551) rochdale
# Processing Record (552) mastic beach
# Processing Record (553) darnah
# Processing Record (554) saint-francois
# Processing Record (555) astoria
# Processing Record (556) beloha
# Processing Record (557) sayyan
# Processing Record (558) chingirlau
# Processing Record (559) shubarshi
# Processing Record (560) japura
# Processing Record (561) linden
# Processing Record (562) mandurah
# Processing Record (563) biltine
# Processing Record (564) appleton
# Processing Record (565) dodge city
# Processing Record (566) acapulco
# Processing Record (567) puerto suarez
# Processing Record (568) high prairie
# Processing Record (569) bandarbeyla
# Processing Record (570) nizhneyansk
# City not found. Skipping...
# Processing Record (571) kudahuvadhoo
# Processing Record (572) muros
# Processing Record (573) bo rai
# Processing Record (574) hilton head island
# Processing Record (575) eau claire
# Processing Record (576) ulaanbaatar
# Processing Record (577) vila franca do campo
# Processing Record (578) synya
# Processing Record (579) mendi
# Processing Record (580) porto nacional
# Processing Record (581) nykoping
# Processing Record (582) mujiayingzi
# Processing Record (583) vao
# Processing Record (584) axim
# Processing Record (585) los llanos de aridane
# Processing Record (586) imeni poliny osipenko
# Processing Record (587) shar
# Processing Record (588) taksimo
# Processing Record (589) coquimbo
# Processing Record (590) sabha
# Processing Record (591) zhigalovo
# Processing Record (592) filingue
# Processing Record (593) bargal
# City not found. Skipping...
# Processing Record (594) dongning
# Processing Record (595) yauya
# Processing Record (596) oslob
# Processing Record (597) povenets
# Processing Record (598) longlac
# City not found. Skipping...
# Processing Record (599) kihei
# Processing Record (600) erdaojiang
# Processing Record (601) walla walla
# Processing Record (602) azimur
# City not found. Skipping...
# Processing Record (603) kunming
# Processing Record (604) richards bay
# Processing Record (605) tirumullaivasal
# Processing Record (606) jinchengjiang
# City not found. Skipping...
# Processing Record (607) kouroussa
# Processing Record (608) cordoba
# Processing Record (609) ixtapa
# Processing Record (610) moose factory

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df_ctf.to_csv('output\cities_weather.csv', encoding='utf-8', index=False)
df_ctf.date = pd.to_datetime(df_ctf.date, unit='s')
df_ctf
# Out:
#                       city  cloudiness country                date  humidity  \
# 0                     Juba          81      EE 2019-11-22 20:29:49        50
# 1               Codrington          40      AU 2019-11-22 20:29:49        93
# 2                   Bethel          90      US 2019-11-22 20:27:17        92
# 3                  Rikitea          61      PF 2019-11-22 20:30:04        83
# 4                 Penzance          75      GB 2019-11-22 20:30:04        93
# 5       Comodoro Rivadavia           0      AR 2019-11-22 20:30:04        39
# 6              Clyde River          90      CA 2019-11-22 20:30:04        92
# 7              Tuktoyaktuk          90      CA 2019-11-22 20:30:04        85
# 8             Punta Arenas          40      CL 2019-11-22 20:26:29        38
# 9                 Ucluelet          75      CA 2019-11-22 20:27:17        81
# 10               Carnarvon           0      ZA 2019-11-22 20:30:05        32
# 11            Puerto Ayora          20      EC 2019-11-22 20:30:05        61
# 12          Saint-Philippe          75      CA 2019-11-22 20:30:26        59
# 13                 Ushuaia          75      AR 2019-11-22 20:27:30        47
# 14                Tasiilaq          20      GL 2019-11-22 20:30:26        68
# 15               Grindavik          90      IS 2019-11-22 20:30:26       100
# 16              Port Perry          90      CA 2019-11-22 20:30:26        69
# 17                Meulaboh         100      ID 2019-11-22 20:30:26        90
# 18             New Norfolk          75      AU 2019-11-22 20:30:27        50
# 19               Busselton           0      AU 2019-11-22 20:30:27        60
# 20               Thinadhoo          53      MV 2019-11-22 20:30:27        78
# 21                 Mataura         100      NZ 2019-11-22 20:30:28        82
# 22                    Bath          20      GB 2019-11-22 20:30:04        87
# 23                  Narsaq          75      GL 2019-11-22 20:30:28        49
# 24                  Kodiak          75      US 2019-11-22 20:30:28        69
# 25      Sault Sainte Marie          90      CA 2019-11-22 20:30:28        63
# 26                  Barrow          33      AR 2019-11-22 20:30:28        36
# 27            Ponta do Sol         100      BR 2019-11-22 20:30:28        87
# 28                  Hegang         100      CN 2019-11-22 20:30:29        92
# 29                Seminole          75      US 2019-11-22 20:30:29        66
# ..                     ...         ...     ...                 ...       ...
# 520   Vila Franca do Campo          40      PT 2019-11-22 20:31:46        88
# 521                  Synya         100      RU 2019-11-22 20:31:47        98
# 522                  Mendi          85      ET 2019-11-22 20:31:47        68
# 523         Porto Nacional          40      BR 2019-11-22 20:31:47        55
# 524               Nykoping          90      SE 2019-11-22 20:31:47       100
# 525            Mujiayingzi         100      CN 2019-11-22 20:31:47        86
# 526                    Vao          68      EE 2019-11-22 20:31:47        49
# 527                   Axim           0      GH 2019-11-22 20:31:47        87
# 528  Los Llanos de Aridane          40      ES 2019-11-22 20:31:47        73
# 529  Imeni Poliny Osipenko         100      RU 2019-11-22 20:31:48        96
# 530                   Shar          95      NG 2019-11-22 20:31:48        75
# 531                Taksimo         100      RU 2019-11-22 20:31:48        82
# 532               Coquimbo          20      CL 2019-11-22 20:31:48        60
# 533                  Sabha           0      LY 2019-11-22 20:31:48        36
# 534              Zhigalovo         100      RU 2019-11-22 20:31:48        97
# 535               Filingue         100      NE 2019-11-22 20:31:48        15
# 536               Dongning         100      CN 2019-11-22 20:31:48        86
# 537                  Yauya          98      PE 2019-11-22 20:31:48        60
# 538                  Oslob          59      PH 2019-11-22 20:31:48        79
# 539               Povenets          99      RU 2019-11-22 20:31:49        79
# 540                  Kihei          20      US 2019-11-22 20:31:49        65
# 541             Erdaojiang         100      CN 2019-11-22 20:31:49        84
# 542            Walla Walla           1      US 2019-11-22 20:31:49        56
# 543                Kunming           0      CN 2019-11-22 20:31:49        87
# 544           Richards Bay         100      ZA 2019-11-22 20:31:49        88
# 545        Tirumullaivasal          89      IN 2019-11-22 20:31:49        73
# 546              Kouroussa         100      GN 2019-11-22 20:31:49        40
# 547                Cordoba          22      AR 2019-11-22 20:31:50        41
# 548                 Ixtapa           5      MX 2019-11-22 20:31:50        69
# 549          Moose Factory           1      CA 2019-11-22 20:31:50        78
#
#        lat     lng  max_temp  wind_speed
# 0    57.82   26.93     30.20       10.29
# 1   -28.95  153.24     71.60        6.93
# 2    60.79 -161.76     24.80       10.29
# 3   -23.12 -134.97     72.61       15.50
# 4    50.12   -5.53     52.00       10.29
# 5   -45.87  -67.48     66.20       11.41
# 6    70.47  -68.59     14.00       11.41
# 7    69.44 -133.03     10.40        3.36
# 8   -53.16  -70.91     60.80       29.97
# 9    48.94 -125.55     48.00        4.70
# 10  -30.97   22.13     63.45       14.05
# 11   -0.74  -90.35     77.00       19.46
# 12   45.36  -73.48     35.60       24.16
# 13  -54.81  -68.31     57.20        5.82
# 14   65.61  -37.64     26.60        2.24
# 15   63.84  -22.43     44.60        1.12
# 16   44.10  -78.95     37.40       17.22
# 17    4.14   96.13     77.74        6.89
# 18  -42.78  147.06     57.99        8.05
# 19  -33.64  115.35     57.00        9.55
# 20    0.53   72.93     82.09       13.38
# 21  -46.19  168.86     54.00        1.01
# 22   51.38   -2.36     48.20       17.22
# 23   60.91  -46.05     26.60        2.24
# 24   39.95  -94.76     34.00        4.70
# 25   46.49  -84.36     28.40        4.70
# 26  -38.31  -60.23     60.91       13.73
# 27  -20.63  -46.00     71.62        3.29
# 28   47.34  130.28     37.67       16.31
# 29   32.72 -102.64     53.60        8.05
# ..     ...     ...       ...         ...
# 520  37.72  -25.43     66.20       19.46
# 521  65.37   58.04     31.17        5.95
# 522   9.80   35.10     66.83        3.69
# 523 -10.70  -48.41     87.80        0.87
# 524  58.75   17.01     42.80       12.75
# 525  42.12  118.78     37.53        1.97
# 526  59.10   26.19     28.35        8.99
# 527   4.87   -2.24     77.50        3.80
# 528  28.66  -17.92     69.80        4.70
# 529  52.42  136.49     16.18        5.30
# 530   7.30    8.73     79.56        4.72
# 531  56.36  114.84    -12.95        4.92
# 532 -29.95  -71.34     68.00       13.87
# 533  27.03   14.43     69.76       11.21
# 534  54.81  105.15     -2.67        3.04
# 535  14.35    3.32     85.64        4.00
# 536  44.06  131.12     31.15        2.91
# 537  -8.99  -77.29     51.64        5.64
# 538   9.52  123.43     81.05       14.94
# 539  62.85   34.83     27.07        6.49
# 540  20.76 -156.45     82.40       18.34
# 541  41.78  126.03     37.00        6.06
# 542  46.06 -118.33     45.00        2.17
# 543  25.04  102.71     48.20       11.18
# 544 -28.77   32.06     72.39       11.95
# 545  11.24   79.84     81.66        9.64
# 546  10.65   -9.88     77.38        2.64
# 547 -27.78  -67.24     85.57       19.26
# 548  20.71 -105.21     84.00       11.41
# 549  51.26  -80.61     15.80       13.87
#
# [550 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
current_date = datetime.date.today().strftime("%m/%d/%y")
chart_title = f'City Latitude vs Max Temperature ({current_date})'
fig = plt.figure()
ax = df_ctf.plot.scatter(x='lat',
                       y='max_temp',
                       c='DarkBlue', title=chart_title)
ax.set_xlabel('Latitude')
ax.set_ylabel('Maxium Temperature (F)')
fig.savefig('output\latitude_vs_temperatur.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
